# %% [markdown]
# # Data Exploration
# This notebook explores raw IoT sensor data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your raw data
data = pd.read_csv('../data/raw/sensors_day1.csv')
data.head()
# Out:
#              timestamp  temperature_C  pressure_bar  flow_rate_lps  \
# 0  2025-04-21 00:00:00          75.99          5.20          88.81
# 1  2025-04-21 00:01:00          74.72          5.35          89.40
# 2  2025-04-21 00:02:00          76.30          5.05          96.97
# 3  2025-04-21 00:03:00          78.05          4.61         102.29
# 4  2025-04-21 00:04:00          74.53          5.12          86.26
#
#    vibration_mms
# 0          1.998
# 1          1.989
# 2          2.122
# 3          1.892
# 4          1.924

# %%
data.describe()
# Out:
#        temperature_C  pressure_bar  flow_rate_lps  vibration_mms
# count    1440.000000   1440.000000    1440.000000    1440.000000
# mean       75.079632      5.007986      99.811660       1.997248
# std         1.974749      0.293379       5.135326       0.098100
# min        68.520000      4.090000      84.960000       1.682000
# 25%        73.727500      4.810000      96.347500       1.934000
# 50%        75.090000      5.000000      99.820000       1.998000
# 75%        76.342500      5.200000     103.170000       2.065000
# max        82.710000      5.960000     119.630000       2.311000

# %%
data.plot(subplots=True, figsize=(12, 8))
plt.show()
